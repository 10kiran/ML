# %%
url='https://github.com/edyoda/data-science-complete-tutorial/blob/master/Data/house_rental_data.csv.txt'
url='https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import math
from scipy import stats
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %matplotlib inline

# %%
df=pd.read_csv(url)

# %%
df
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0             1  1177.698      2           7        2            2         2
# 1             2  2134.800      5           7        4            2         2
# 2             3  1138.560      5           7        2            2         1
# 3             4  1458.780      2           7        3            2         2
# 4             5   967.776     11          14        3            2         2
# ..          ...       ...    ...         ...      ...          ...       ...
# 640         644  1359.156      7          15        3            2         2
# 641         645   377.148      4          10        1            1         1
# 642         646   740.064     13          14        1            1         1
# 643         647  1707.840      3          14        3            2         2
# 644         648  1376.946      6           7        3            2         1
#
#      Price
# 0    62000
# 1    78000
# 2    58000
# 3    45000
# 4    45000
# ..     ...
# 640  45000
# 641  24800
# 642  45000
# 643  65000
# 644  36000
#
# [645 rows x 8 columns]

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 0    1177.698      2           7        2            2         2  62000
# 1    2134.800      5           7        4            2         2  78000
# 2    1138.560      5           7        2            2         1  58000
# 3    1458.780      2           7        3            2         2  45000
# 4     967.776     11          14        3            2         2  45000
# ..        ...    ...         ...      ...          ...       ...    ...
# 640  1359.156      7          15        3            2         2  45000
# 641   377.148      4          10        1            1         1  24800
# 642   740.064     13          14        1            1         1  45000
# 643  1707.840      3          14        3            2         2  65000
# 644  1376.946      6           7        3            2         1  36000
#
# [645 rows x 7 columns]

# %% [markdown]
# # 1. Insights into the data

# %%
rows,cols=df.shape
print('Number of rows : ',rows,'\nNumber of columns : ',cols)
# Out:
# Number of rows :  645
# Number of columns :  7

# %%
df.describe()
# Out:
#               Sqft       Floor  TotalFloor     Bedroom  Living.Room  \
# count   645.000000  645.000000  645.000000  645.000000   645.000000
# mean   1527.656260    5.939535   10.855814    2.837209     1.813953
# std     767.386531    3.884721    4.996208    1.010740     0.462364
# min     359.358000    1.000000    1.000000    1.000000     0.000000
# 25%     925.080000    3.000000    7.000000    2.000000     2.000000
# 50%    1423.200000    5.000000   12.000000    3.000000     2.000000
# 75%    1892.856000    8.000000   14.000000    4.000000     2.000000
# max    5856.468000   22.000000   38.000000    7.000000     4.000000
#
#          Bathroom          Price
# count  645.000000     645.000000
# mean     1.810853   61986.823256
# std      0.683574   35635.091007
# min      0.000000    6100.000000
# 25%      1.000000   39000.000000
# 50%      2.000000   50000.000000
# 75%      2.000000   75000.000000
# max      5.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sqft         645 non-null    float64
#  1   Floor        645 non-null    int64
#  2   TotalFloor   645 non-null    int64
#  3   Bedroom      645 non-null    int64
#  4   Living.Room  645 non-null    int64
#  5   Bathroom     645 non-null    int64
#  6   Price        645 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 35.4 KB

# %%
df.isnull().sum()
# Out:
# Sqft           0
# Floor          0
# TotalFloor     0
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
df.rename({'Living.Room':'Livingroom'},axis=1,inplace=True)

# %%
df
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# 0    1177.698      2           7        2           2         2  62000
# 1    2134.800      5           7        4           2         2  78000
# 2    1138.560      5           7        2           2         1  58000
# 3    1458.780      2           7        3           2         2  45000
# 4     967.776     11          14        3           2         2  45000
# ..        ...    ...         ...      ...         ...       ...    ...
# 640  1359.156      7          15        3           2         2  45000
# 641   377.148      4          10        1           1         1  24800
# 642   740.064     13          14        1           1         1  45000
# 643  1707.840      3          14        3           2         2  65000
# 644  1376.946      6           7        3           2         1  36000
#
# [645 rows x 7 columns]

# %% [markdown]
# # 2.Visualization

# %%
sns.displot(df['Price'],color='red',bins=10)

# %%
sns.pairplot(df,kind='reg')

# %%
sns.jointplot(x='Sqft',y='Price',data=df,kind='reg')

# %%
plt.pie(df['Floor'].value_counts(),labels=df['Floor'].value_counts().index,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # 3. Managing data for training and testing

# %%
# the dataset
df
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# 0    1177.698      2           7        2           2         2  62000
# 1    2134.800      5           7        4           2         2  78000
# 2    1138.560      5           7        2           2         1  58000
# 3    1458.780      2           7        3           2         2  45000
# 4     967.776     11          14        3           2         2  45000
# ..        ...    ...         ...      ...         ...       ...    ...
# 640  1359.156      7          15        3           2         2  45000
# 641   377.148      4          10        1           1         1  24800
# 642   740.064     13          14        1           1         1  45000
# 643  1707.840      3          14        3           2         2  65000
# 644  1376.946      6           7        3           2         1  36000
#
# [645 rows x 7 columns]

# %% [markdown]
# ### Pre-processing

# %%
# Dealing with outliers using z-score
z = np.abs(stats.zscore(df)) # z-score for each entry


df_o = df[(z < 3).all(axis=1)].reset_index(drop=True)  # removing entries above threshold of z-score 3

# %%
df.shape , df_o.shape
# Out:
# ((645, 7), (608, 7))

# %%
df_o
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# 0    1177.698      2           7        2           2         2  62000
# 1    2134.800      5           7        4           2         2  78000
# 2    1138.560      5           7        2           2         1  58000
# 3    1458.780      2           7        3           2         2  45000
# 4     967.776     11          14        3           2         2  45000
# ..        ...    ...         ...      ...         ...       ...    ...
# 603  1359.156      7          15        3           2         2  45000
# 604   377.148      4          10        1           1         1  24800
# 605   740.064     13          14        1           1         1  45000
# 606  1707.840      3          14        3           2         2  65000
# 607  1376.946      6           7        3           2         1  36000
#
# [608 rows x 7 columns]

# %%
# choosing features using correlation
corr = df_o.corr()

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# We choose just the features whose correlation with target column(Price) is greater than 0.5
corr['Price'][corr['Price']>0.5]
# Out:
# Sqft        0.758197
# Bathroom    0.536768
# Price       1.000000
# Name: Price, dtype: float64

# %%
# So, Features would be
Features=['Sqft','Bathroom']

# %%
# The features
X = df[Features]

# The target
Y = df['Price']

# %%
X.head()
# Out:
#        Sqft  Bathroom
# 0  1177.698         2
# 1  2134.800         2
# 2  1138.560         1
# 3  1458.780         2
# 4   967.776         2

# %%
Y.head()
# Out:
# 0    62000
# 1    78000
# 2    58000
# 3    45000
# 4    45000
# Name: Price, dtype: int64

# %%
# Scaling the feature dataset using standard dataset
scaler=StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[-0.45639303  0.27691822]
#  [ 0.79179777  0.27691822]
#  [-0.50743429 -1.18711665]
#  ...
#  [-1.02712711 -1.18711665]
#  [ 0.23498403  0.27691822]
#  [-0.19654662 -1.18711665]]

# %%
# Splitting these datasets into training and testing
x_train,x_test,y_train,y_test=train_test_split(X_scaled,Y,test_size=0.25,random_state=7)

# %%
# Checking splitted data
x_train.shape
# Out:
# (483, 2)

# %%
y_train.shape
# Out:
# (483,)

# %%
x_test.shape
# Out:
# (162, 2)

# %%
y_test.shape
# Out:
# (162,)

# %% [markdown]
# # 4. Modelling and finding better value for k

# %%
# Modelling using a k value of 5
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_train,y_train) # fitting the model
y_pred=model.predict(x_test) # predicting values

# calculating root mean squared error (RMSE)
error = math.sqrt(mean_squared_error(y_test,y_pred))
print(error)
# Out:
# 19170.592169083702

# %%
rmse_val=[]
for i in range(1,51):
    model=KNeighborsRegressor(n_neighbors=i)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    error=math.sqrt(mean_squared_error(y_test,y_pred))
    rmse_val.append((error,i))
print(rmse_val)
# Out:
# [(20702.602170938517, 1), (18307.14742382984, 2), (19369.06883083954, 3), (19235.827212295313, 4), (19170.592169083702, 5), (18459.456698108283, 6), (18142.811214581703, 7), (17592.521399386893, 8), (17746.21798057714, 9), (17585.882314784336, 10), (17219.08797050726, 11), (16636.864114201275, 12), (16526.341882596233, 13), (16421.124643184132, 14), (16675.608033492113, 15), (16555.42949916326, 16), (16386.56418664351, 17), (16304.82680221243, 18), (16236.328850153197, 19), (16220.80228141846, 20), (16166.233564719403, 21), (16229.00128253924, 22), (16367.86493120001, 23), (16284.565190856247, 24), (16323.511156094777, 25), (16394.26024511864, 26), (16438.140943807197, 27), (16453.633168071698, 28), (16512.958087456707, 29), (16564.937668943425, 30), (16715.62077271526, 31), (16787.258149946807, 32), (16741.11629365372, 33), (16698.53385930465, 34), (16595.9719598212, 35), (16632.997528214688, 36), (16608.40230290122, 37), (16661.296014113457, 38), (16530.71463969805, 39), (16636.91873594782, 40), (16657.008795993446, 41), (16725.193592077416, 42), (16827.729463933338, 43), (16792.878275001298, 44), (16755.403314246076, 45), (16788.085206728487, 46), (16822.30363580519, 47), (16773.55185095533, 48), (16818.672262115633, 49), (16827.71161686631, 50)]

# %%
# Getting minimum RMSE value
print(min(rmse_val))
# Out:
# (16166.233564719403, 21)

# %% [markdown]
# ### Since RMSE is lowest at k value of 21 in tested range of 1 to 50, it is to be considered to be optimal

# %%
# Modelling using k value of 21
model=KNeighborsRegressor(n_neighbors=21)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
# Final predicted values alond with true values
pd.DataFrame(data={'Prediction':y_pred,'Actual':y_test})
# Out:
#         Prediction  Actual
# 582   47095.190476   45000
# 221   72809.476190   55000
# 333  134745.904762  160000
# 70    37861.809524   25000
# 586   40025.142857   43000
# ..             ...     ...
# 541   50560.809524   31000
# 23    60899.428571  105000
# 273   31166.619048   17000
# 384   66456.619048   44000
# 644   50061.904762   36000
#
# [162 rows x 2 columns]

# %% [markdown]
# # Using all columns as features

# %%
df_o
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Livingroom  Bathroom  Price
# 0    1177.698      2           7        2           2         2  62000
# 1    2134.800      5           7        4           2         2  78000
# 2    1138.560      5           7        2           2         1  58000
# 3    1458.780      2           7        3           2         2  45000
# 4     967.776     11          14        3           2         2  45000
# ..        ...    ...         ...      ...         ...       ...    ...
# 603  1359.156      7          15        3           2         2  45000
# 604   377.148      4          10        1           1         1  24800
# 605   740.064     13          14        1           1         1  45000
# 606  1707.840      3          14        3           2         2  65000
# 607  1376.946      6           7        3           2         1  36000
#
# [608 rows x 7 columns]

# %%
X=df_o.iloc[:,:6]  #Features
Y=df_o.iloc[:,6]  #Target

# %%
# Scaling using Standard scaler
scaler=StandardScaler()
X_all_scaled = scaler.fit_transform(X)
X_all_scaled
# Out:
# array([[-0.42671271, -1.1029462 , -0.75886491, -0.827359  ,  0.44150012,
#          0.44722506],
#        [ 1.10409925, -0.16984144, -0.75886491,  1.24274088,  0.44150012,
#          0.44722506],
#        [-0.48931097, -0.16984144, -0.75886491, -0.827359  ,  0.44150012,
#         -1.32998302],
#        ...,
#        [-1.12667506,  2.31843792,  0.77108727, -1.86240894, -1.99879144,
#         -1.32998302],
#        [ 0.42120916, -0.79191128,  0.77108727,  0.20769094,  0.44150012,
#          0.44722506],
#        [-0.10803067,  0.14119348, -0.75886491,  0.20769094,  0.44150012,
#         -1.32998302]])

# %%
# Splitting these datasets into training and testing

x_train,x_test,y_train,y_test=train_test_split(X_all_scaled,Y,test_size=0.25,random_state=7)

# %%
# Finding optimal value of k so that RMSE is minimum

rmse_val=[]
for i in range(1,51):
    model=KNeighborsRegressor(n_neighbors=i)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    error=math.sqrt(mean_squared_error(y_test,y_pred))
    rmse_val.append((error,i))
print(rmse_val)
# Out:
# [(20513.29087894506, 1), (19428.11835694459, 2), (19414.573095512405, 3), (18173.80536171932, 4), (18000.250042027925, 5), (18241.312317738604, 6), (18121.198095203647, 7), (18091.883324873925, 8), (17867.340779806822, 9), (17838.496378183718, 10), (17544.33443617766, 11), (17652.64933728726, 12), (17848.73910083958, 13), (17739.930237026896, 14), (17621.211801811427, 15), (17849.708195437357, 16), (18089.662407055916, 17), (18111.404161106664, 18), (18182.999697534193, 19), (18108.680183231714, 20), (18018.11001371604, 21), (18032.580880832873, 22), (17909.66375535093, 23), (17958.36876556715, 24), (17966.142560805867, 25), (17864.88674414864, 26), (17889.01634748199, 27), (17947.22717659639, 28), (18048.861528806643, 29), (18181.16261743318, 30), (18096.4915253418, 31), (18112.949632996395, 32), (18156.33431850822, 33), (18220.37772283779, 34), (18302.54963162976, 35), (18365.549571719937, 36), (18287.443837941642, 37), (18340.666371079078, 38), (18345.9027526164, 39), (18415.873436966416, 40), (18415.56689133177, 41), (18439.77719772692, 42), (18433.363834573734, 43), (18429.82651770905, 44), (18485.82005449783, 45), (18413.200194188597, 46), (18374.253244825282, 47), (18424.309884187533, 48), (18432.463194328826, 49), (18375.46057690807, 50)]

# %%
# Getting minimum RMSE value
print(min(rmse_val))
# Out:
# (17544.33443617766, 11)

# %% [markdown]
# ### Since RMSE is lowest at k value of 11 in tested range of 1 to 50, it is to be considered to be optimal

# %%
# Modelling using k value of 11
model=KNeighborsRegressor(n_neighbors=11)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
# Final predicted values alond with true values
pd.DataFrame(data={'Prediction':y_pred,'Actual':y_test})
# Out:
#        Prediction  Actual
# 401  41345.454545   51000
# 283  54116.090909   44999
# 414  73454.454545   78000
# 482  78444.363636   70000
# 419  51135.454545   45000
# ..            ...     ...
# 323  48772.727273   39000
# 593  54363.636364   45000
# 289  58890.818182   37000
# 409  35805.818182   28000
# 159  31305.818182   37000
#
# [152 rows x 2 columns]
